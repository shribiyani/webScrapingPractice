# %% [markdown]
# # webScraping -
#
# - Two ways to extract data from a website:
#     - **Use the API of website** (if, exists)[ex. Facebook APi, Twitter API, Amazon API, etc.]
#     - **Web Scraping / Web Harvesting / Web Data Extraction**- means accessing the HTML page  of website and extracting useful / required information / data from it.

# %% [markdown]
# ### Steps involved in scraping -
#
# 1. **Send an HTTP request to the URL of website** - access to the particular website, result the server reponds to the request by returning HTML content of site.
#     - **requests package** is used
#
# 2. **Parsing The Data** - after getting accessed to the HTML content, we have to parse the data. Reason for it is -
#     - HTML data is nested & we cannot extract required data
#     - Create a Nested / Tree Structure of the HTML data.
#     - **html5lib** most advanced pacakage for parsing
#
# 3. **Tree Traversal** - navigating & searching the parse tree which created in Step 2.
#     - **BeautifulSoup** - pulling data from **HTML** & **XML** files

# %% [markdown]
# #### Step - 1: Installing & Loading Reuored Third-party Packages
#
# - **Installing 3rd-party libraries** -
#     - !pip install requests
#     - !pip install html5lib
#     - !pip install bs4
#
# > **pip** -  a **package management system** used to **install and manage software packages** written in Python.

# %%
# Installing 3rd-party libraries

# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\sharmila_biyani\anaconda3\envs\webcrawl\lib\site-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sharmila_biyani\anaconda3\envs\webcrawl\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sharmila_biyani\anaconda3\envs\webcrawl\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sharmila_biyani\anaconda3\envs\webcrawl\lib\site-packages (from requests) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\sharmila_biyani\anaconda3\envs\webcrawl\lib\site-packages (from requests) (4.0.0)

# %%
# !pip install html5lib
# Out:
# Collecting html5lib
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: webencodings in c:\users\sharmila_biyani\anaconda3\envs\webcrawl\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\sharmila_biyani\anaconda3\envs\webcrawl\lib\site-packages (from html5lib) (1.15.0)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\sharmila_biyani\anaconda3\envs\webcrawl\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\sharmila_biyani\anaconda3\envs\webcrawl\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sharmila_biyani\anaconda3\envs\webcrawl\lib\site-packages (from beautifulsoup4->bs4) (2.2)

# %% [markdown]
# - **Loading Required Packages**-
#     - import requests
#     - import html5lib
#     - from bs4 import BeautifulSoup
#     - import csv

# %%
# Loading Required Packages
import csv
import requests
import html5lib
from bs4 import BeautifulSoup

# %% [markdown]
# #### Task 2 : Accessing HTML content from website

# %%
url = 'https://www.geeksforgeeks.org/data-structures/' # specify the URL of site want to scrape
r = requests.get(url) # send HTTP request to specified URL & save response from server in a response object, i.e., 'r'
print(r.content) # gives raw HTML content of website, it's of'sting' type
# Out:
# b'<!DOCTYPE html>\r\n<!--[if IE 7]>\r\n<html class="ie ie7" lang="en-US" prefix="og: http://ogp.me/ns#">\r\n<![endif]-->\r\n<!--[if IE 8]>\r\n<html class="ie ie8" lang="en-US" prefix="og: http://ogp.me/ns#">\r\n<![endif]-->\r\n<!--[if !(IE 7) | !(IE 8)  ]><!-->\r\n<html lang="en-US" prefix="og: http://ogp.me/ns#" >\r\n\r\n<!--<![endif]-->\r\n<head>\r\n<meta charset="UTF-8" />\r\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"> \r\n\r\n<link rel="shortcut icon" href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" type="image/x-icon" />\r\n<meta name="theme-color" content="#308D46" />\r\n\r\n<meta property="og:image" content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_200x200-min.png">\r\n<meta property="og:image:type" content="image/png">\r\n<meta property="og:image:width" content="200">\r\n<meta property="og:image:height" content="200">\r\n<script defer src="https://apis.google.com/js/platform.js"></script>\r\n<script async src="//cdnjs.cloudflare.com/ajax/libs/require.js/2.1.14/require.min.js"></script>\r\n<!-- <link rel="stylesheet" href="https://use.typekit.net/mrg0hpc.css"/> -->\r\n<link rel="stylesheet" href="https://use.typekit.net/atk5goj.css"/>\r\n\r\n<title>Data Structures - GeeksforGeeks</title>\r\n<link rel="profile" href="http://gmpg.org/xfn/11" />\r\n<link rel="pingback" href="" />\r\n<!--[if lt IE 9]>\r\n<script src="https://www.geeksforgeeks.org/wp-content/themes/iconic-one/js/html5.js" type="text/javascript"></script>\r\n<![endif]-->\r\n<script type="application/ld+json">\r\n    {\r\n        "@context" : "http://schema.org",\r\n        "@type" : "Organization",\r\n        "name" : "GeeksforGeeks",\r\n        "url" : "https://www.geeksforgeeks.org/",\r\n        "logo" : "https://media.geeksforgeeks.org/wp-content/cdn-uploads/20200817185016/gfg_complete_logo_2x-min.png",\r\n        "description" : "A computer science portal for geeks. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions.",\r\n        "founder": [\r\n            {\r\n                "@type" : "Person",\r\n                "name" : "Sandeep Jain",\r\n                "url" : "https://in.linkedin.com/in/sandeep-jain-b3940815"\r\n            }\r\n        ],\r\n        "sameAs" : [ "https://www.facebook.com/geeksforgeeks.org/",\r\n            "https://twitter.com/geeksforgeeks",\r\n            "https://www.linkedin.com/company/1299009",\r\n            "https://www.youtube.com/geeksforgeeksvideos/"\r\n        ]\r\n    }\r\n</script>\r\n<script>\r\n\r\n    var arrPostCat = new Array();\r\n        var tIds = "";\r\n    var domain = 1;\r\n    var arrPost = new Array();\r\n    var post_id = "125686";\r\n    var post_type = "page";\r\n    var post_slug = window.location.href;\r\n    var ip = "34.223.241.120";\r\n    var post_title = "Data Structures";\r\n    var post_status = "publish";\r\n    var post_date = "2014-02-01 20:16:50";\r\n                            var isAdminLoggedIn = 0;\r\n        </script>\r\n\n<!-- This site is optimized with the Yoast SEO plugin v7.6 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="description" content="Complete list of Data Structure, Practice Problems, Quizzes, Array, Linked List, Stack, Queue, Trees, Heap, Graph, Matrix, Advanced Data Structures"/>\n<link rel="canonical" href="https://www.geeksforgeeks.org/data-structures/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Data Structures - GeeksforGeeks" />\n<meta property="og:description" content="Complete list of Data Structure, Practice Problems, Quizzes, Array, Linked List, Stack, Queue, Trees, Heap, Graph, Matrix, Advanced Data Structures" />\n<meta property="og:url" content="https://www.geeksforgeeks.org/data-structures/" />\n<meta property="og:site_name" content="GeeksforGee ...

# %% [markdown]
# #### Task 3 : Parsing the HTML content

# %%
url = 'http://www.values.com/inspirational-quotes'
page = requests.get(url)

soup = BeautifulSoup(page.content, 'html5lib') # page.content = raw HTML Content, 'html5lib' = HTML parser
print(soup.prettify()) # gives visual representation of the parse three created from raw HTML content.

# BeautifulSoup built on the HTML parsing libraries [ as, 'html5lib', 'lxml', 'html.parser', etc]
# So BeautifulSoup object and specify the parser library can be created at the same time.
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US">
#  <head>
#   <title>
#    Inspirational Quotes - Motivational Quotes - Leadership Quotes | PassItOn.com
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1" name="viewport"/>
#   <meta content="The Foundation for a Better Life | Pass It On.com" name="description"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#c8102e" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#c8102e" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
#   <link href="/assets/application-a6ca07ae6273ea6a53035ee258f9dd78.css" media="all" rel="stylesheet"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content
width="310"/>
#       </a>
#       <h5 class="value_on_red">
#        <a href="/inspirational-quotes/7403-as-is-our-confidence-so-is-our-capacity">
#         CONFIDENCE
#        </a>
#       </h5>
#      </div>
#      <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#       <a href="/inspirational-quotes/8188-what-lies-behind-you-and-what-lies-in-front-of">
#        <img alt="What lies behind you and what lies in front of you pales in comparison to what lies inside you.  #&lt;Author:0x00007f5ebf0bc528&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8188/medium/20200210_wednesday_quote.jpg?1612472831" width="310"/>
#       </a>
#       <h5 class="value_on_red">
#        <a href="/inspirational-quotes/8188-what-lies-behind-you-and-what-lies-in-front-of">
#         CONFIDENCE
#        </a>
#       </h5>
#      </div>
#      <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#       <a href="/inspirational-quotes/8187-live-from-the-heart-of-yourself-seek-to-be">
#        <img alt="Live from the heart of yourself. Seek to be whole, not perfect. #&lt;Author:0x00007f5ebf10c690&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8187/medium/20200209_tuesday_quote.jpg?1612472818" width="310"/>
#       </a>
#       <h5 class="value_on_red">
#        <a href="/inspirational-quotes/8187-live-from-the-heart-of-yourself-seek-to-be">
#         CONFIDENCE
#        </a>
#       </h5>
#      </div>
#      <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#       <a href="/inspirational-quotes/8186-personality-begins-where-comparison-leaves-off">
#        <img alt="Personality begins where comparison leaves off. Be unique. Be memorable. Be confident. Be proud. #&lt;Author:0x00007f5ebf144f90&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8186/medium/20200208_monday_quote.jpg?1612472804" width="310"/>
#       </a>
#       <h5 class="value_on_red">
#        <a href="/inspirational-quotes/8186-personality-begins-where-comparison-leaves-off">
#         CONFIDENCE
#        </a>
#       </h5>
#      </div>
#      <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#       <a href="/inspirational-quotes/8185-bravery-shows-up-in-everyday-life-when-people">
#        <img alt="Bravery shows up in everyday life when people have the courage to live their truth, their vision and their dreams. #&lt;Author:0x00007f5ebf17a410&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8185/medium/20210205_friday_quote.jpg?1611954012" width="310"/>
#       </a>
#       <h5 class="value_on_red">
#        <a href="/inspirational-quotes/8185-bravery-shows-up-in-everyday-life-when-people">
#         BRAVERY
#        </a>
#       </h5>
#      </div>
#      <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#       <a href="/inspirational-quotes/8184-only-when-were-brave-enough-to-explore-the">
#        <img alt="Only when we're brave enough to explore the darkness will we discover the infinite power of our light. #&lt;Author:0x00007f5ebf1b6488&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8184/medium/20210204_thursday_quote.jpg?1611953982" width="310"/>
#       </a>
#       <h5 class="value_on_red">
#        <a href="/inspirational-quotes/8184-only-when-were-brave-enough-to-explore-the">
#         BRAVERY
#        </a>
#       </h5>
#      </div>
#      <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#       <a href="/inspirational-quotes/8183-bravery-is-the-audacity-to-be-unhindered-by">
#        <img alt="Bravery is the audacity to be unhindered by failures, and to walk with freedom, strength, and hope, in the face of things unknown. #&lt;Author:0x00007f5ebf20d170&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8183/medium/20210203_wednesday_quote.jpg?1611953956" width="310"/>
#       </a>
#       <h5 class="value_on_red">
#        <a href="/inspirational-quotes/8183-bravery-is-the-audacity-to-be-unhindered-by">
#         BRAVERY
#        </a>
#       </h5>
#      </div>
#      <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#       <a href="/inspirational-quotes/7863-be-brave-take-risks-nothing-can-substitute">
#        <img alt="Be brave. Take risks. Nothing can substitute experience. #&lt;Author:0x00007f5ebf246e98&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7863/medium/20210202_tuesday_quote.jpg?1611953930" width="310"/>
#       </a>
#       <h5 class="value_on_red">
#        <a href="/inspirational-quotes/7863-be-brave-take-risks-nothing-can-substitute">
#         BRAVERY
#        </a>
#       </h5>
#      </div>
#      <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#       <a href="/inspirational-quotes/8182-there-is-always-light-if-only-were-brave">
#        <img alt="There is always light, if only we're brave enough to see it. If only we're brave enough to be it. #&lt;Author:0x00007f5ebf2708d8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8182/medium/20210201_monday_quote.jpg?1611953899" width="310"/>
#       </a>
#       <h5 class="value_on_red">
#        <a href="/inspirational-quotes/8182-there-is-always-light-if-only-were-brave">
#         BRAVERY
#        </a>
#       </h5>
#      </div>
#      <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#       <a href="/inspirational-quotes/6682-give-me-six-hours-to-chop-down-a-tree-and-i">
#        <img alt="Give me six hours to chop down a tree, and I will spend the first four sharpening the axe. #&lt;Author:0x00007f5ebf2a8648&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6682/medium/20210129_friday_quote.jpg?1611274490" width="310"/>
#       </a>
#       <h5 class="value_on_red">
#        <a href="/inspirational-quotes/6682-give-me-six-hours-to-chop-down-a-tree-and-i">
#         PREPARATION
#        </a>
#       </h5>
#      </div>
#     </div>
#     <div class="row">
#      <div class="col-12 text-center">
#       <div class="quotes_pagination">
#        <span class="previous_page disabled">
#         ← Previous
#        </span>
#        <em class="current">
#         1
#        </em>
#        <a href="/inspirational-quotes?page=2" rel="next">
#         2
#        </a>
#        <a href="/inspirational-quotes?page=3">
#         3
#        </a>
#        <a href="/inspirational-quotes?page=4">
#         4
#        </a>
#        <a href="/inspirational-quotes?page=5">
#         5
#        </a>
#        <a href="/inspirational-quotes?page=6">
#         6
#        </a>
#        <a href="/inspirational-quotes?page=7">
#         7
#        </a>
#        <a href="/inspirational-quotes?page=8">
#         8
#        </a>
#        <a href="/inspirational-quotes?page=9">
#         9
#        </a>
#        <span class="gap">
#         …
#        </span>
#        <a href="/inspirational-quotes?page=120">
#         120
#        </a>
#        <a href="/inspirational-quotes?page=121">
#         121
#        </a>
#        <a class="next_page" href="/inspirational-quotes?page=2" rel="next">
#         Next →
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <footer class="footer-classic-dark bg-extra-dark-gray padding-five-bottom sm-padding-30px-bottom">
#    <div class="bg-dark-footer padding-50px-tb sm-padding-30px-tb">
#     <div class="container">
#      <div class="row align-items-center">
#       <div class="col-lg-4 col-md-4 sm-text-center lg-text-left alt-font sm-margin-15px-bottom">
#        <a href="/">
#         <img alt="PassItOn.com The Foundation for a Better Life" data-rjs="/assets/site/passiton_fbl_logo-078fc8bdd27f7ef8c76cf23b391f16e3.png" src="/assets/site/passiton_fbl_logo-078fc8bdd27f7ef8c76cf23b391f16e3.png" style="max-width: 200px;"/>
#        </a>
#       </div>
#       <div class="col-lg-4 col-md-4 text-center sm-margin-10px-bottom">
#       </div>
#       <div class="col-lg-4 col-md-4 text-center">
#        <span class="alt-font margin-20px-right">
#         Follow us on social
#        </span>
#        <div class="social-icon-style-8 d-inline-block vertical-align-middle">
#         <ul class="small-icon mb-0">
#          <li>
#           <a class="facebook text-white-2" href="https://www.facebook.com/valuescom" target="_blank">
#            <i aria-hidden="true" class="fab fa-facebook-f">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="twitter text-white-2" href="https://twitter.com/passiton_values" target="_blank">
#            <i class="fab fa-twitter">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="instagram text-white-2" href="https://www.instagram.com/passiton_values/" target="_blank">
#            <i aria-hidden="true" class="fab fa-instagram no-margin-right">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="pinterest text-white-2" href="https://www.pinterest.com/passiton_values/" target="_blank">
#            <i aria-hidden="true" class="fab fa-pinterest no-margin-right">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="youtube text-white-2" href="https://www.youtube.com/c/passiton_values" target="_blank">
#            <i aria-hidden="true" class="fab fa-youtube no-margin-right">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="footer-widget-area padding-five-top padding-30px-bottom sm-padding-30px-top">
#     <div class="container">
#      <div class="row">
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         About Us
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small" href="/who-we-are">
#           About The Foundation for a Better Life
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/faqs">
#           FAQs
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/foundation-recognition">
#           Foundation Recognition
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/contact-us">
#           Contact Us
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         Be Inspired
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small" href="/teaching-values">
#           Teaching Values
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/inspirational-quotes">
#           Inspirational Quotations
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/inspirational-stories-tv-spots">
#           Pass It On® Videos
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/newspaper-stories">
#           Free Newspaper Stories
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/your-everyday-heroes">
#           Who's Your Hero Stories
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/inspirational-sayings-billboards">
#           Official Billboard Campaign
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/your-billboards">
#           Create Your Own Billboard
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/radio">
#           Radio Ads
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/passiton-blog">
#           Pass It On® Blog
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/inspirational-audio-stories">
#           Podcasts
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/pass-it-on-ecards">
#           Send an Ecard
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         For Schools
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small" href="/poster-requests/new">
#           Free Posters &amp; DVD for Schools
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="/pass-it-on-downloads">
#           Downloads
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         For Media Companies
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small" href="/for-media-companies">
#           For Media Companies
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="https://www.passiton-media.com">
#           Broadcast Quality PSA Downloads
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="https://www.passiton-media.com">
#           Pass It On Radio Ads
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="https://www.passiton-media.com">
#           Live Reads
#          </a>
#         </li>
#         <li>
#          <a class="text-small" href="https://www.passiton-media.com">
#           Out of Home Materials
#          </a>
#         </li>
#        </ul>
#        <div class="row sm-margin-30px-top">
#         <div class="col-lg-4">
#          <a href="/">
#           <img alt="Values logo" src="/assets/site/values_logo-cd29ec5f2f086673ac42962263d07e02.png" style="max-width: 70px;"/>
#          </a>
#         </div>
#         <div class="col-lg-7">
#          <p class="text-medium-gray text-small padding-10px-top">
#           VALUES.COM
#           <small>
#            ®
#           </small>
#           is now PassItOn.com
#           <small>
#            ®
#           </small>
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="footer-bottom border-top border-color-medium-dark-gray padding-30px-top">
#      <div class="row">
#       <div class="col-lg-6 col-md-6 text-small text-md-left text-center">
#        ©2000-2021 The Foundation for a Better Life.
#       </div>
#       <div class="col-lg-6 col-md-6 text-small text-md-right text-center">
#        <a href="/privacy-policy">
#         Privacy Policy
#        </a>
#        |
#        <a href="/terms-of-use">
#         Terms of Use
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <a class="scroll-top-arrow" href="javascript:void(0);">
#    <i class="ti-arrow-up">
#    </i>
#   </a>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/1.12.4/jquery.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-UO2eT0CpHqdSJQ6hJty5KVphtPhzWj9WO1clHTMGa3JDZwrnQq4sF86dIHNDz0W1" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js">
#   </script>
#   <script src="/assets/pofo-3d0d89a27285d93c09e0f4c1fc85cead.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# #### Task 4 : Searching & Navigating through the Parse Tree
#
# - extract some useful data from HTML Content.
# - The soup object contains all the data in the nested structure which could be programmatically extracted.
#
#
# >**Scraping Quotes**.

# %%
# loading URL
url = 'http://www.values.com/inspirational-quotes'

# sending HTTP request
page = requests.get(url)

# Creating HTML Parser
soup = BeautifulSoup(page.content, 'html5lib')

quotes = [] # a list to store quotes

tables = soup.find('div', attrs = {'id':'all_quotes'})

for row in tables.findAll('div', class_ = 'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'):
    quote = {}
    quote['theme'] = row.h5.text
    quote['url'] = row.a['href']
    quote['img'] = row.img['src']
    quote['lines'] = row.img['alt'].split(' #')[0]
    quote['author'] = row.img['alt'].split(' #')[1]
    quotes.append(quote)

filename = 'inspirational_quotes.csv'
with open(filename, 'w', newline = '') as f:
    w = csv.DictWriter(f, ['theme', 'url', 'img', 'lines', 'author'])
    w.writeheader()
    for quote in quotes:
        w.writerow(quote)

# %% [markdown]
# **Step 4 : worl by line**
# - tag.**find()** - return the first matching element
#     - **'div'** argument - HTML tag we want to search.
#     - **class_** argument - a dictionary type element to specify the additional attributes associated with that tag.**find()**
#
#     - table.**prettify()**
#     - tag.**findALL()** - returns a list of all matching elements

# %%
print(tables.prettify())
# Out:
# <div class="row" id="all_quotes">
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/7826-the-world-needs-dreamers-and-the-world-needs">
#    <img alt="The world needs dreamers and the world needs doers. But above all what the world needs most are dreamers that do. #&lt;Author:0x0000557555ead380&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7826/medium/20210316_tuesday_quote.jpg?1615507606" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/7826-the-world-needs-dreamers-and-the-world-needs">
#     INNOVATION
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/7824-what-good-is-an-idea-if-it-remains-an-idea">
#    <img alt="What good is an idea if it remains an idea? Try. Experiment. Iterate. Fail. Try again. Change the world. #&lt;Author:0x00005575560d13a0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7824/medium/20210315_monday_quote.jpg?1615507581" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/7824-what-good-is-an-idea-if-it-remains-an-idea">
#     INNOVATION
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/7031-nobody-grows-old-by-merely-living-a-number-of">
#    <img alt="Nobody grows old by merely living a number of years. People grow old by deserting their ideals. Years may wrinkle the skin, but to give up wrinkles the soul. #&lt;Author:0x00005575577de548&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7031/medium/20210312_friday_quote.jpg?1614900784" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/7031-nobody-grows-old-by-merely-living-a-number-of">
#     DETERMINATION
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/3926-fall-seven-times-stand-up-eight">
#    <img alt="Fall seven times, stand up eight. #&lt;Author:0x00005575578a76f0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/3926/medium/20210311_thursday_quote.jpg?1614900744" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/3926-fall-seven-times-stand-up-eight">
#     DETERMINATION
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8195-some-succeed-because-they-are-destined-to-but">
#    <img alt="Some succeed because they are destined to, but most succeed because they are determined to. #&lt;Author:0x00005575579359a0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8195/medium/20210310_wednesday_quote.jpg?1614900721" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8195-some-succeed-because-they-are-destined-to-but">
#     DETERMINATION
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/6714-if-you-have-made-mistakes-even-serious-ones">
#    <img alt="If you have made mistakes, even serious ones, there is always another chance for you.  What we call failure is not the falling down, but the staying down. #&lt;Author:0x000055755799fc88&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6714/medium/20210309_tuesday_quote.jpg?1614900696" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/6714-if-you-have-made-mistakes-even-serious-ones">
#     DETERMINATION
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/4218-there-is-no-chance-no-destiny-no-fate-that">
#    <img alt="There is no chance, no destiny, no fate, that can hinder or control the firm resolve of a determined soul. #&lt;Author:0x0000557557aa83a0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/4218/medium/20210308_monday_quote.jpg?1614900669" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/4218-there-is-no-chance-no-destiny-no-fate-that">
#     DETERMINATION
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8194-friendship-is-a-strong-and-habitual-inclination">
#    <img alt="Friendship is a strong and habitual inclination in two persons to promote the good and happiness of one another. #&lt;Author:0x0000557557c8bc80&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8194/medium/20210305_friday_quote.jpg?1614384615" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8194-friendship-is-a-strong-and-habitual-inclination">
#     FRIENDSHIP
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/7438-the-most-beautiful-discovery-true-friends-make">
#    <img alt="The most beautiful discovery true friends make is that they can grow separately without growing apart. #&lt;Author:0x0000557557d7beb0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7438/medium/20210304_thursday_quote.jpg?1614384591" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/7438-the-most-beautiful-discovery-true-friends-make">
#     FRIENDSHIP
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8193-friends-are-the-family-you-choose">
#    <img alt="Friends are the family you choose. #&lt;Author:0x0000557557fa6140&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8193/medium/20210303_wednesday_quote.jpg?1614384566" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8193-friends-are-the-family-you-choose">
#     FRIENDSHIP
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8192-anything-is-possible-when-you-have-the-right">
#    <img alt="Anything is possible when you have the right people there to support you. #&lt;Author:0x00005575580a45d8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8192/medium/20210302_tuesday_quote.jpg?1614384547" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8192-anything-is-possible-when-you-have-the-right">
#     FRIENDSHIP
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/7641-friends-are-medicine-for-a-wounded-heart-and">
#    <img alt="Friends are medicine for a wounded heart and vitamins for a hopeful soul. #&lt;Author:0x0000557558205170&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/
width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8189-believing-that-the-dots-will-connect-down-the">
#     CONFIDENCE
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/7403-as-is-our-confidence-so-is-our-capacity">
#    <img alt="As is our confidence, so is our capacity. #&lt;Author:0x000055755891f758&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7403/medium/20200211_thursday_quote.jpg?1612472845" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/7403-as-is-our-confidence-so-is-our-capacity">
#     CONFIDENCE
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8188-what-lies-behind-you-and-what-lies-in-front-of">
#    <img alt="What lies behind you and what lies in front of you pales in comparison to what lies inside you.  #&lt;Author:0x000055755893e388&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8188/medium/20200210_wednesday_quote.jpg?1612472831" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8188-what-lies-behind-you-and-what-lies-in-front-of">
#     CONFIDENCE
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8187-live-from-the-heart-of-yourself-seek-to-be">
#    <img alt="Live from the heart of yourself. Seek to be whole, not perfect. #&lt;Author:0x0000557558967350&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8187/medium/20200209_tuesday_quote.jpg?1612472818" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8187-live-from-the-heart-of-yourself-seek-to-be">
#     CONFIDENCE
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8186-personality-begins-where-comparison-leaves-off">
#    <img alt="Personality begins where comparison leaves off. Be unique. Be memorable. Be confident. Be proud. #&lt;Author:0x0000557558989d88&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8186/medium/20200208_monday_quote.jpg?1612472804" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8186-personality-begins-where-comparison-leaves-off">
#     CONFIDENCE
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8185-bravery-shows-up-in-everyday-life-when-people">
#    <img alt="Bravery shows up in everyday life when people have the courage to live their truth, their vision and their dreams. #&lt;Author:0x00005575589a0948&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8185/medium/20210205_friday_quote.jpg?1611954012" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8185-bravery-shows-up-in-everyday-life-when-people">
#     BRAVERY
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8184-only-when-were-brave-enough-to-explore-the">
#    <img alt="Only when we're brave enough to explore the darkness will we discover the infinite power of our light. #&lt;Author:0x00005575589b52f8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8184/medium/20210204_thursday_quote.jpg?1611953982" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8184-only-when-were-brave-enough-to-explore-the">
#     BRAVERY
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8183-bravery-is-the-audacity-to-be-unhindered-by">
#    <img alt="Bravery is the audacity to be unhindered by failures, and to walk with freedom, strength, and hope, in the face of things unknown. #&lt;Author:0x00005575589cab58&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8183/medium/20210203_wednesday_quote.jpg?1611953956" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8183-bravery-is-the-audacity-to-be-unhindered-by">
#     BRAVERY
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/7863-be-brave-take-risks-nothing-can-substitute">
#    <img alt="Be brave. Take risks. Nothing can substitute experience. #&lt;Author:0x00005575589de5b8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7863/medium/20210202_tuesday_quote.jpg?1611953930" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/7863-be-brave-take-risks-nothing-can-substitute">
#     BRAVERY
#    </a>
#   </h5>
#  </div>
#  <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#   <a href="/inspirational-quotes/8182-there-is-always-light-if-only-were-brave">
#    <img alt="There is always light, if only we're brave enough to see it. If only we're brave enough to be it. #&lt;Author:0x00005575589f4b88&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8182/medium/20210201_monday_quote.jpg?1611953899" width="310"/>
#   </a>
#   <h5 class="value_on_red">
#    <a href="/inspirational-quotes/8182-there-is-always-light-if-only-were-brave">
#     BRAVERY
#    </a>
#   </h5>
#  </div>
# </div>

# %%
import pandas as pd

file = pd.read_csv('inspirational_quotes.csv',encoding='cp1252')

# if their is utf-8 codec error - use "cp1252" as encoding

file
# Out:
#             theme                                                url  \
# 0      INNOVATION  /inspirational-quotes/7826-the-world-needs-dre...
# 1      INNOVATION  /inspirational-quotes/7824-what-good-is-an-ide...
# 2   DETERMINATION  /inspirational-quotes/7031-nobody-grows-old-by...
# 3   DETERMINATION  /inspirational-quotes/3926-fall-seven-times-st...
# 4   DETERMINATION  /inspirational-quotes/8195-some-succeed-becaus...
# 5   DETERMINATION  /inspirational-quotes/6714-if-you-have-made-mi...
# 6   DETERMINATION  /inspirational-quotes/4218-there-is-no-chance-...
# 23  https://assets.passiton.com/quotes/quote_artwo...
# 24  https://assets.passiton.com/quotes/quote_artwo...
# 25  https://assets.passiton.com/quotes/quote_artwo...
# 26  https://assets.passiton.com/quotes/quote_artwo...
# 27  https://assets.passiton.com/quotes/quote_artwo...
# 28  https://assets.passiton.com/quotes/quote_artwo...
# 29  https://assets.passiton.com/quotes/quote_artwo...
# 30  https://assets.passiton.com/quotes/quote_artwo...
# 31  https://assets.passiton.com/quotes/quote_artwo...
#
#                                                 lines  \
# 0   The world needs dreamers and the world needs d...
# 1   What good is an idea if it remains an idea? Tr...
# 2   Nobody grows old by merely living a number of ...
# 3                   Fall seven times, stand up eight.
# 4   Some succeed because they are destined to, but...
# 5   If you have made mistakes, even serious ones, ...
# 6   There is no chance, no destiny, no fate, that ...
# 7   Friendship is a strong and habitual inclinatio...
# 8   The most beautiful discovery true friends make...
# 9                  Friends are the family you choose.
# 10  Anything is possible when you have the right p...
# 11  Friends are medicine for a wounded heart and v...
# 12  Find life experiences and swallow them whole. ...
# 13  Do not let making a living prevent you from ma...
# 14  You have brains in your head. You have feet in...
# 15  The person who has lived the most is not the o...
# 16  Life itself is a privilege. But to live life t...
# 17  Your circumstance doesn’t make life extraordin...
# 18  And still, after all this time, the Sun has ne...
# 19  You yourself, as much as anybody in the entire...
# 20  The best thing to hold onto in life is each ot...
# 21                       Let us see what love can do.
# 22  Believing that the dots will connect down the ...
# 23          As is our confidence, so is our capacity.
# 24  What lies behind you and what lies in front of...
# 25  Live from the heart of yourself. Seek to be wh...
# 26  Personality begins where comparison leaves off...
# 27  Bravery shows up in everyday life when people ...
# 28  Only when we're brave enough to explore the da...
# 29  Bravery is the audacity to be unhindered by fa...
# 30  Be brave. Take risks. Nothing can substitute e...
# 31  There is always light, if only we're brave eno...
#
#                          author
# 0   <Author:0x0000557555ead380>
# 1   <Author:0x00005575560d13a0>
# 2   <Author:0x00005575577de548>
# 3   <Author:0x00005575578a76f0>
# 4   <Author:0x00005575579359a0>
# 5   <Author:0x000055755799fc88>
# 6   <Author:0x0000557557aa83a0>
# 7   <Author:0x0000557557c8bc80>
# 8   <Author:0x0000557557d7beb0>
# 9   <Author:0x0000557557fa6140>
# 10  <Author:0x00005575580a45d8>
# 11  <Author:0x0000557558205170>
# 12  <Author:0x00005575583389e8>
# 13  <Author:0x0000557558404598>
# 14  <Author:0x0000557558458c10>
# 15  <Author:0x00005575584dfb20>
# 16  <Author:0x000055755851b148>
# 17  <Author:0x0000557558568790>
# 18  <Author:0x000055755858e8a0>
# 19  <Author:0x00005575585b6c60>
# 20  <Author:0x00005575585ccc68>
# 21  <Author:0x00005575585eda30>
# 22  <Author:0x00005575588f4c38>
# 23  <Author:0x000055755891f758>
# 24  <Author:0x000055755893e388>
# 25  <Author:0x0000557558967350>
# 26  <Author:0x0000557558989d88>
# 27  <Author:0x00005575589a0948>
# 28  <Author:0x00005575589b52f8>
# 29  <Author:0x00005575589cab58>
# 30  <Author:0x00005575589de5b8>
# 31  <Author:0x00005575589f4b88>
